# %%
# !pip install pandas

# %%
import pandas as pd

dataframe_sampah = pd.read_excel('data_jabar.xlsx', sheet_name='data')
dataframe_sampah
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
#No. 2
tahun = 2020
jumlah = 0

for index, row in dataframe_sampah.iterrows():
    if row['tahun'] == tahun:
        jumlah = jumlah + row['jumlah_produksi_sampah']

print(f"Total Produksi Sampah Pada Tahun 2020 Adalah {jumlah:.2f} ton")
# Out:
# Total Produksi Sampah Pada Tahun 2020 Adalah 25333.00 ton

# %%
#No.3
total_pertahun = {}

for i, row in dataframe_sampah.iterrows():
    tahun = row['tahun']
    jumlah = row['jumlah_produksi_sampah']
    
    if pd.isna(jumlah):
        jumlah = 0

    total_pertahun[tahun] = total_pertahun.get(tahun, 0) + jumlah

print('Total Produksi Sampah Pertahun :')
for thn, jmlh in total_pertahun.items():
    print(f'Tahun {thn} : {jmlh:.2f} ton')
# Out:
# Total Produksi Sampah Pertahun :
# Tahun 2015 : 20969.27 ton
# Tahun 2016 : 20969.27 ton
# Tahun 2017 : 20969.27 ton
# Tahun 2018 : 22772.92 ton
# Tahun 2019 : 24490.56 ton
# Tahun 2020 : 25333.00 ton
# Tahun 2021 : 15735.36 ton
# Tahun 2022 : 0.00 ton
# Tahun 2023 : 0.00 ton

# %%
#No.4
total_kotakabupaten_pertahun = {}

for i, row in dataframe_sampah.iterrows():
    daerah = row['nama_kabupaten_kota']
    jumlah = row['jumlah_produksi_sampah']
    
    if pd.isna(jumlah):
        jumlah = 0

    total_kotakabupaten_pertahun[daerah] = total_kotakabupaten_pertahun.get(daerah, 0) + jumlah

print('Total Produksi Sampah PerKota/Kabupaten Pertahun :')
for dae, jmlh in total_kotakabupaten_pertahun.items():
    print(f'Tahun {dae} : {jmlh:.2f} ton')
# Out:
# Total Produksi Sampah PerKota/Kabupaten Pertahun :
# Tahun KABUPATEN BOGOR : 13113.49 ton
# Tahun KABUPATEN SUKABUMI : 4038.19 ton
# Tahun KABUPATEN CIANJUR : 6497.92 ton
# Tahun KABUPATEN BANDUNG : 11934.04 ton
# Tahun KABUPATEN GARUT : 4484.29 ton
# Tahun KABUPATEN TASIKMALAYA : 3531.33 ton
# Tahun KABUPATEN CIAMIS : 2329.72 ton
# Tahun KABUPATEN KUNINGAN : 2486.63 ton
# Tahun KABUPATEN CIREBON : 3205.17 ton
# Tahun KABUPATEN MAJALENGKA : 2593.39 ton
# Tahun KABUPATEN SUMEDANG : 2532.71 ton
# Tahun KABUPATEN INDRAMAYU : 5383.18 ton
# Tahun KABUPATEN SUBANG : 4735.53 ton
# Tahun KABUPATEN PURWAKARTA : 2262.90 ton
# Tahun KABUPATEN KARAWANG : 5997.44 ton
# Tahun KABUPATEN BEKASI : 11328.27 ton
# Tahun KABUPATEN BANDUNG BARAT : 4972.37 ton
# Tahun KABUPATEN PANGANDARAN : 1277.55 ton
# Tahun KOTA BOGOR : 5952.47 ton
# Tahun KOTA SUKABUMI : 1833.73 ton
# Tahun KOTA BANDUNG : 14521.78 ton
# Tahun KOTA CIREBON : 1887.57 ton
# Tahun KOTA BEKASI : 15504.31 ton
# ...

# %%
dataframe_sampah.to_csv('data_produksi_sampah_jabar.csv', index=False)
dataframe_sampah.to_excel('data_produksi_sampah_jabar.xlsx', index=False)
